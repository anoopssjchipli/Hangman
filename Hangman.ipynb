# %%
# %run hangman_words.ipynb
# %run hangman_logo.ipynb

# %%
#Randomly choose a word and assign it to a variable called chosen_word
import random

chosen_word = random.choice(word_list)




#Create a empty list called display. For each letter in the chosen word, add a '_' to display.
word_length = len(chosen_word)
display_word = list()
for i in range(word_length):
    display_word.append('_')
#print(display_word)
temp_display = display_word

#creating a variable called 'lives' to keep track of player's lives. Total lives is 6
#if the guessed letter is not in chosen_word then reduce the lives by 1. It should print "you lose" after all lives hits 0
lives = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

#Ask user to guess a letter and assign the letter to variable called guess.make guess in lowercase
#Loop through each position in the chosen_word; if a letter at that position matches the word add those letters position.
#check if the letter guessed is one of the letter in chosen_word
#use a while loop to keep asking user for a input until all blanks are filled and then print if all are filled
eog = '_'
eol=6
while eog in temp_display and eol>-1:
    guess = input('Guess the Word !')
    ite=0
    for letter in chosen_word:
        if guess == letter:
            temp_display[ite] = guess
        ite+=1
    if guess not in chosen_word:
        print(lives[eol])
        eol-=1        
#3print display and you should see guessed letters in that position and rest being '_'
    print(temp_display)

if eol<0:
    print('You Lose')
    print(f'The word was {chosen_word}')
else:
    print(f"Congrats you guessed the word. The word is {chosen_word}") 
    print("You Win !")
# Out:
# Guess the Word !a
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Guess the Word !e
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Guess the Word !i
# ['_', 'i', '_', '_', '_', '_', '_', '_', '_']
# Guess the Word !o
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# ['_', 'i', '_', '_', '_', '_', '_', '_', '_']
# Guess the Word !u
# ['_', 'i', '_', '_', '_', '_', '_', 'u', '_']
# Guess the Word !s
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# ['_', 'i', '_', '_', '_', '_', '_', 'u', '_']
# Guess the Word !r
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
# ['_', 'i', '_', '_', '_', '_', '_', 'u', '_']
# Guess the Word !h
# ['_', 'i', '_', 'h', '_', '_', '_', 'u', '_']
# Guess the Word !n
# ['n', 'i', '_', 'h', '_', '_', '_', 'u', '_']
# Guess the Word !o
#
#   +---+
#   |   |
#   O   |
#  /|\  |
# ...
